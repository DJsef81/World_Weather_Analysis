# %%
# Create a new set of 2,000 random latitudes and longitudes.

# %%
# Create Latitude and Longitude Combinations

# %%
# import the Pandas, Matplotlib, and NumPy dependencies in the first cell, and run the cell.

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 763

# %%
# Perform an API call with the OpenWeatherMap.

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32d9b44c37f623141c5d4159e7a8d47e

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Retrieve the following information from the API call:

# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country":city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | mogadishu
# Processing Record 3 of Set 1 | katsuura
# Processing Record 4 of Set 1 | dikson
# Processing Record 5 of Set 1 | harper
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | chokurdakh
# Processing Record 10 of Set 1 | kingsport
# Processing Record 11 of Set 1 | mahebourg
# Processing Record 12 of Set 1 | salalah
# Processing Record 13 of Set 1 | okmulgee
# Processing Record 14 of Set 1 | saint george
# Processing Record 15 of Set 1 | gayeri
# Processing Record 16 of Set 1 | jamestown
# Processing Record 17 of Set 1 | port alfred
# Processing Record 18 of Set 1 | chengde
# Processing Record 19 of Set 1 | moen
# Processing Record 20 of Set 1 | avarua
# Processing Record 21 of Set 1 | raudeberg
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | rikitea
# Processing Record 24 of Set 1 | bereda
# Processing Record 25 of Set 1 | faanui
# Processing Record 26 of Set 1 | pangody
# Processing Record 27 of Set 1 | mount vernon
# Processing Record 28 of Set 1 | vaini
# Processing Record 29 of Set 1 | qaanaaq
# Processing Record 30 of Set 1 | katesh
# Processing Record 31 of Set 1 | tuktoyaktuk
# Processing Record 32 of Set 1 | abnub
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | magdagachi
# Processing Record 35 of Set 1 | husavik
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | dillon
# Processing Record 38 of Set 1 | yellowknife
# Processing Record 39 of Set 1 | talnakh
# Processing Record 40 of Set 1 | tiksi
# Processing Record 41 of Set 1 | roma
# Processing Record 42 of Set 1 | ambon
# Processing Record 43 of Set 1 | puerto ayora
# Processing Record 44 of Set 1 | busselton
# Processing Record 45 of Set 1 | coihaique
# Processing Record 46 of Set 1 | banjar
# Processing Record 47 of Set 1 | dodoma
# Processing Record 48 of Set 1 | camacha
# Processing Record 49 of Set 1 | rajura
# Processing Record 50 of Set 1 | guanica
# Processing Record 1 of Set 2 | hilo
# Processing Record 2 of Set 2 | saint-augustin
# Processing Record 3 of Set 2 | maragogi
# Processing Record 4 of Set 2 | atuona
# Processing Record 5 of Set 2 | bayshore gardens
# Processing Record 6 of Set 2 | pa sang
# Processing Record 7 of Set 2 | hamilton
# Processing Record 8 of Set 2 | palmer
# Processing Record 9 of Set 2 | albany
# Processing Record 10 of Set 2 | cape town
# Processing Record 11 of Set 2 | kavaratti
# Processing Record 12 of Set 2 | touros
# Processing Record 13 of Set 2 | deputatskiy
# Processing Record 14 of Set 2 | ca mau
# Processing Record 15 of Set 2 | gao
# Processing Record 16 of Set 2 | necochea
# Processing Record 17 of Set 2 | bilma
# Processing Record 18 of Set 2 | charters towers
# Processing Record 19 of Set 2 | sao filipe
# Processing Record 20 of Set 2 | mataura
# Processing Record 21 of Set 2 | vila franca do campo
# Processing Record 22 of Set 2 | orotukan
# Processing Record 23 of Set 2 | khatanga
# Processing Record 24 of Set 2 | samandag
# Processing Record 25 of Set 2 | praskoveya
# Processing Record 26 of Set 2 | hithadhoo
# Processing Record 27 of Set 2 | ribeira grande
# Processing Record 28 of Set 2 | san patricio
# Processing Record 29 of Set 2 | juneau
# Processing Record 30 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 2 | hasaki
# Processing Record 33 of Set 2 | skjervoy
# Processing Record 34 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 2 | luderitz
# Processing Record 36 of Set 2 | corrente
# Processing Record 37 of Set 2 | georgetown
# Processing Record 38 of Set 2 | katobu
# Processing Record 39 of Set 2 | barrow
# Processing Record 40 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 2 | dharchula
# Processing Record 42 of Set 2 | lavrentiya
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | carnarvon
# Processing Record 45 of Set 2 | grand forks
# Processing Record 46 of Set 2 | atherton
# Processing Record 47 of Set 2 | kallifitos
# Processing Record 48 of Set 2 | te anau
# Processing Record 49 of Set 2 | przhevalskoye
# Processing Record 50 of Set 2 | tabligbo
# Processing Record 1 of Set 3 | manaus
# Processing Record 2 of Set 3 | victoria
# Processing Record 3 of Set 3 | kirillov
# Processing Record 4 of Set 3 | talara
# Processing Record 5 of Set 3 | sioux lookout
# Processing Record 6 of Set 3 | clyde river
# Processing Record 7 of Set 3 | nikolskoye
# Processing Record 8 of Set 3 | haines junction
# Processing Record 9 of Set 3 | amalapuram
# Processing Record 10 of Set 3 | anadyr
# Processing Record 11 of Set 3 | longyearbyen
# Processing Record 12 of Set 3 | armacao dos buzios
# City not found. Skipping...
# Processing Record 13 of Set 3 | xadani
# City not found. Skipping...
# Processing Record 14 of Set 3 | sitka
# Processing Record 15 of Set 3 | pathein
# Processing Record 16 of Set 3 | nome
# Processing Record 17 of Set 3 | cherskiy
# Processing Record 18 of Set 3 | yulara
# Processing Record 19 of Set 3 | gualaquiza
# Processing Record 20 of Set 3 | morehead
# Processing Record 21 of Set 3 | cidreira
# Processing Record 22 of Set 3 | khipro
# Processing Record 23 of Set 3 | houma
# Processing Record 24 of Set 3 | kushiro
# Processing Record 25 of Set 3 | butaritari
# Processing Record 26 of Set 3 | la asuncion
# Processing Record 27 of Set 3 | mar del plata
# Processing Record 28 of Set 3 | junction city
# Processing Record 29 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 3 | balikpapan
# Processing Record 31 of Set 3 | esperance
# Processing Record 32 of Set 3 | bandarbeyla
# Processing Record 33 of Set 3 | arraial do cabo
# Processing Record 34 of Set 3 | honningsvag
# Processing Record 35 of Set 3 | saskylakh
# Processing Record 36 of Set 3 | porangatu
# Processing Record 37 of Set 3 | geraldton
# Processing Record 38 of Set 3 | uruzgan
# Processing Record 39 of Set 3 | bonoua
# Processing Record 40 of Set 3 | pisco
# Processing Record 41 of Set 3 | tangping
# Processing Record 42 of Set 3 | bodden town
# Processing Record 43 of Set 3 | unidos
# Processing Record 44 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 3 | yerbogachen
# Processing Record 46 of Set 3 | caravelas
# Processing Record 47 of Set 3 | naze
# Processing Record 48 of Set 3 | bredasdorp
# Processing Record 49 of Set 3 | castro
# Processing Record 50 of Set 3 | karibib
# Processing Record 1 of Set 4 | hovd
# Processing Record 2 of Set 4 | miri
# Processing Record 3 of Set 4 | souillac
# Processing Record 4 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 5 of Set 4 | namibe
# Processing Record 6 of Set 4 | chuy
# Processing Record 7 of Set 4 | kemijarvi
# Processing Record 8 of Set 4 | santa maria
# Processing Record 9 of Set 4 | hualmay
# Processing Record 10 of Set 4 | provideniya
# Processing Record 11 of Set 4 | kaitangata
# Processing Record 12 of Set 4 | grand-santi
# Processing Record 13 of Set 4 | kodiak
# Processing Record 14 of Set 4 | baculin
# Processing Record 15 of Set 4 | laguna
# Processing Record 16 of Set 4 | hakkari
# Processing Record 17 of Set 4 | arkadak
# Processing Record 18 of Set 4 | devonport
# Processing Record 19 of Set 4 | mount gambier
# Processing Record 20 of Set 4 | gimli
# Processing Record 21 of Set 4 | pacatuba
# Processing Record 22 of Set 4 | takab
# Processing Record 23 of Set 4 | wladyslawowo
# Processing Record 24 of Set 4 | shingu
# Processing Record 25 of Set 4 | pangnirtung
# Processing Record 26 of Set 4 | sao jose da coroa grande
# Processing Record 27 of Set 4 | coquimbo
# Processing Record 28 of Set 4 | ostrovnoy
# Processing Record 29 of Set 4 | thompson
# Processing Record 30 of Set 4 | lebu
# Processing Record 31 of Set 4 | lompoc
# Processing Record 32 of Set 4 | severo-kurilsk
# Processing Record 33 of Set 4 | atbasar
# Processing Record 34 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 4 | zhigansk
# Processing Record 36 of Set 4 | strangnas
# Processing Record 37 of Set 4 | upernavik
# Processing Record 38 of Set 4 | bambous virieux
# Processing Record 39 of Set 4 | abha
# Processing Record 40 of Set 4 | kruisfontein
# Processing Record 41 of Set 4 | arlit
# Processing Record 42 of Set 4 | santa teresa
# Processing Record 43 of Set 4 | chitungwiza
# Processing Record 44 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 45 of Set 4 | yelovo
# Processing Record 46 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 47 of Set 4 | black river
# Processing Record 48 of Set 4 | andenes
# Processing Record 49 of Set 4 | itaunja
# Processing Record 50 of Set 4 | osny
# Processing Record 1 of Set 5 | otavi
# Processing Record 2 of Set 5 | castro verde
# Processing Record 3 of Set 5 | ancud
# Processing Record 4 of Set 5 | natchez
# Processing Record 5 of Set 5 | belmonte
# Processing Record 6 of Set 5 | oudtshoorn
# Processing Record 7 of Set 5 | aklavik
# Processing Record 8 of Set 5 | salinopolis
# Processing Record 9 of Set 5 | edd
# Processing Record 10 of Set 5 | vao
# Processing Record 11 of Set 5 | puerto el triunfo
# Processing Record 12 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 5 | saint pete beach
# Processing Record 14 of Set 5 | campobasso
# Processing Record 15 of Set 5 | ust-nera
# Processing Record 16 of Set 5 | jiazi
# Processing Record 17 of Set 5 | bengkulu
# Processing Record 18 of Set 5 | maumere
# Processing Record 19 of Set 5 | yar-sale
# Processing Record 20 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 5 | marawi
# Processing Record 22 of Set 5 | krasnovishersk
# Processing Record 23 of Set 5 | brebes
# Processing Record 24 of Set 5 | riwaka
# Processing Record 25 of Set 5 | asau
# Processing Record 26 of Set 5 | morondava
# Processing Record 27 of Set 5 | kidal
# Processing Record 28 of Set 5 | fairbanks
# Processing Record 29 of Set 5 | barcelos
# Processing Record 30 of Set 5 | taunggyi
# Processing Record 31 of Set 5 | isangel
# Processing Record 32 of Set 5 | faya
# Processing Record 33 of Set 5 | meulaboh
# Processing Record 34 of Set 5 | tautira
# Processing Record 35 of Set 5 | broken hill
# Processing Record 36 of Set 5 | pevek
# Processing Record 37 of Set 5 | aljezur
# Processing Record 38 of Set 5 | oxford
# Processing Record 39 of Set 5 | manadhoo
# Processing Record 40 of Set 5 | lagoa
# Processing Record 41 of Set 5 | sovetskiy
# Processing Record 42 of Set 5 | karratha
# Processing Record 43 of Set 5 | ponta do sol
# Processing Record 44 of Set 5 | phra phutthabat
# Processing Record 45 of Set 5 | ilulissat
# Processing Record 46 of Set 5 | chiria
# Processing Record 47 of Set 5 | palu
# Processing Record 48 of Set 5 | quatre cocos
# Processing Record 49 of Set 5 | talcahuano
# Processing Record 50 of Set 5 | tasbuget
# City not found. Skipping...
# Processing Record 1 of Set 6 | vardo
# Processing Record 2 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 3 of Set 6 | cairns
# Processing Record 4 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 5 of Set 6 | leh
# Processing Record 6 of Set 6 | riyadh
# Processing Record 7 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 8 of Set 6 | sambava
# Processing Record 9 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 6 | mafeteng
# Processing Record 11 of Set 6 | tanout
# Processing Record 12 of Set 6 | mae hong son
# Processing Record 13 of Set 6 | surt
# Processing Record 14 of Set 6 | tambovka
# Processing Record 15 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 16 of Set 6 | fortuna
# Processing Record 17 of Set 6 | stephenville
# Processing Record 18 of Set 6 | abu kamal
# Processing Record 19 of Set 6 | bethel
# Processing Record 20 of Set 6 | obidos
# Processing Record 21 of Set 6 | kamenka
# Processing Record 22 of Set 6 | ahipara
# Processing Record 23 of Set 6 | la ronge
# Processing Record 24 of Set 6 | cabo san lucas
# Processing Record 25 of Set 6 | vestmannaeyjar
# Processing Record 26 of Set 6 | polis
# Processing Record 27 of Set 6 | babra
# Processing Record 28 of Set 6 | poso
# Processing Record 29 of Set 6 | nantucket
# Processing Record 30 of Set 6 | okato
# Processing Record 31 of Set 6 | biltine
# Processing Record 32 of Set 6 | galesong
# Processing Record 33 of Set 6 | saldanha
# Processing Record 34 of Set 6 | polson
# Processing Record 35 of Set 6 | rundu
# Processing Record 36 of Set 6 | puerto escondido
# Processing Record 37 of Set 6 | rodeo
# Processing Record 38 of Set 6 | pirojpur
# Processing Record 39 of Set 6 | buchanan
# Processing Record 40 of Set 6 | kalianget
# Processing Record 41 of Set 6 | airai
# Processing Record 42 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 43 of Set 6 | zeya
# Processing Record 44 of Set 6 | kisoro
# Processing Record 45 of Set 6 | haibowan
# City not found. Skipping...
# Processing Record 46 of Set 6 | tura
# Processing Record 47 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 48 of Set 6 | panacan
# Processing Record 49 of Set 6 | port elizabeth
# Processing Record 50 of Set 6 | xinqing
# Processing Record 1 of Set 7 | torbay
# Processing Record 2 of Set 7 | altonia
# City not found. Skipping...
# Processing Record 3 of Set 7 | arona
# Processing Record 4 of Set 7 | bac lieu
# Processing Record 5 of Set 7 | dickinson
# Processing Record 6 of Set 7 | falmouth
# Processing Record 7 of Set 7 | srednekolymsk
# Processing Record 8 of Set 7 | kavieng
# Processing Record 9 of Set 7 | alice springs
# Processing Record 10 of Set 7 | saint-philippe
# Processing Record 11 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 12 of Set 7 | olafsvik
# Processing Record 13 of Set 7 | aksarka
# Processing Record 14 of Set 7 | tocopilla
# Processing Record 15 of Set 7 | daud khel
# Processing Record 16 of Set 7 | sidney
# Processing Record 17 of Set 7 | fomboni
# Processing Record 18 of Set 7 | port augusta
# Processing Record 19 of Set 7 | east london
# Processing Record 20 of Set 7 | sisimiut
# Processing Record 21 of Set 7 | toora-khem
# Processing Record 22 of Set 7 | maraba
# Processing Record 23 of Set 7 | okhotsk
# Processing Record 24 of Set 7 | qovlar
# Processing Record 25 of Set 7 | hennenman
# Processing Record 26 of Set 7 | kyra
# Processing Record 27 of Set 7 | codrington
# Processing Record 28 of Set 7 | vestmanna
# Processing Record 29 of Set 7 | manacapuru
# Processing Record 30 of Set 7 | eidfjord
# Processing Record 31 of Set 7 | lodwar
# Processing Record 32 of Set 7 | cabedelo
# Processing Record 33 of Set 7 | ayagoz
# Processing Record 34 of Set 7 | lagos
# Processing Record 35 of Set 7 | jauja
# Processing Record 36 of Set 7 | la paz
# Processing Record 37 of Set 7 | santiago del estero
# Processing Record 38 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 39 of Set 7 | gallup
# Processing Record 40 of Set 7 | guerrero negro
# Processing Record 41 of Set 7 | along
# Processing Record 42 of Set 7 | wanning
# Processing Record 43 of Set 7 | xining
# Processing Record 44 of Set 7 | mentok
# City not found. Skipping...
# Processing Record 45 of Set 7 | tigzirt
# Processing Record 46 of Set 7 | bayevo
# Processing Record 47 of Set 7 | walvis bay
# Processing Record 48 of Set 7 | odweyne
# Processing Record 49 of Set 7 | port hedland
# Processing Record 50 of Set 7 | verkhnyaya maksakovka
# Processing Record 1 of Set 8 | klaksvik
# Processing Record 2 of Set 8 | aksu
# Processing Record 3 of Set 8 | luganville
# Processing Record 4 of Set 8 | axim
# Processing Record 5 of Set 8 | sept-iles
# Processing Record 6 of Set 8 | shimoda
# Processing Record 7 of Set 8 | ingham
# Processing Record 8 of Set 8 | kuppam
# Processing Record 9 of Set 8 | sikonge
# Processing Record 10 of Set 8 | morro bay
# Processing Record 11 of Set 8 | tumaco
# Processing Record 12 of Set 8 | bababe
# City not found. Skipping...
# Processing Record 13 of Set 8 | leningradskiy
# Processing Record 14 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 15 of Set 8 | nizwa
# Processing Record 16 of Set 8 | emerald
# Processing Record 17 of Set 8 | tadine
# Processing Record 18 of Set 8 | pucallpa
# Processing Record 19 of Set 8 | heswall
# Processing Record 20 of Set 8 | nha trang
# Processing Record 21 of Set 8 | beibei
# Processing Record 22 of Set 8 | kamyshin
# Processing Record 23 of Set 8 | svetlyy
# Processing Record 24 of Set 8 | norman wells
# Processing Record 25 of Set 8 | mandera
# Processing Record 26 of Set 8 | kyabram
# Processing Record 27 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 28 of Set 8 | northam
# Processing Record 29 of Set 8 | romanovka
# Processing Record 30 of Set 8 | constitucion
# Processing Record 31 of Set 8 | rio grande
# Processing Record 32 of Set 8 | chimore
# Processing Record 33 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 34 of Set 8 | rawson
# Processing Record 35 of Set 8 | jiexiu
# Processing Record 36 of Set 8 | novikovo
# Processing Record 37 of Set 8 | san julian
# Processing Record 38 of Set 8 | forestville
# Processing Record 39 of Set 8 | poum
# Processing Record 40 of Set 8 | korla
# Processing Record 41 of Set 8 | hwange
# Processing Record 42 of Set 8 | dwarka
# Processing Record 43 of Set 8 | pittsfield
# Processing Record 44 of Set 8 | whitehorse
# Processing Record 45 of Set 8 | hami
# Processing Record 46 of Set 8 | mergui
# City not found. Skipping...
# Processing Record 47 of Set 8 | price
# Processing Record 48 of Set 8 | padang
# Processing Record 49 of Set 8 | san jose
# Processing Record 50 of Set 8 | mayya
# Processing Record 1 of Set 9 | sobolevo
# Processing Record 2 of Set 9 | panorama
# Processing Record 3 of Set 9 | port macquarie
# Processing Record 4 of Set 9 | cayenne
# Processing Record 5 of Set 9 | arawa
# Processing Record 6 of Set 9 | nouadhibou
# Processing Record 7 of Set 9 | barroso
# Processing Record 8 of Set 9 | ushtobe
# Processing Record 9 of Set 9 | cedar city
# Processing Record 10 of Set 9 | natal
# Processing Record 11 of Set 9 | nizhniy baskunchak
# Processing Record 12 of Set 9 | kutum
# Processing Record 13 of Set 9 | koboldo
# City not found. Skipping...
# Processing Record 14 of Set 9 | xai-xai
# Processing Record 15 of Set 9 | muros
# Processing Record 16 of Set 9 | anyksciai
# Processing Record 17 of Set 9 | berlevag
# Processing Record 18 of Set 9 | san juan
# Processing Record 19 of Set 9 | mareeba
# Processing Record 20 of Set 9 | todos santos
# Processing Record 21 of Set 9 | coahuayana
# Processing Record 22 of Set 9 | medea
# Processing Record 23 of Set 9 | mitsamiouli
# Processing Record 24 of Set 9 | liezen
# Processing Record 25 of Set 9 | chuguyevka
# Processing Record 26 of Set 9 | nabire
# Processing Record 27 of Set 9 | tuatapere
# Processing Record 28 of Set 9 | yenagoa
# Processing Record 29 of Set 9 | derzhavinsk
# Processing Record 30 of Set 9 | clarence town
# Processing Record 31 of Set 9 | wampusirpi
# City not found. Skipping...
# Processing Record 32 of Set 9 | churachandpur
# Processing Record 33 of Set 9 | half moon bay
# Processing Record 34 of Set 9 | tangwani
# Processing Record 35 of Set 9 | eppstein
# Processing Record 36 of Set 9 | north myrtle beach
# Processing Record 37 of Set 9 | meyungs
# City not found. Skipping...
# Processing Record 38 of Set 9 | waingapu
# Processing Record 39 of Set 9 | coos bay
# Processing Record 40 of Set 9 | port-cartier
# Processing Record 41 of Set 9 | khandyga
# Processing Record 42 of Set 9 | hobyo
# Processing Record 43 of Set 9 | ossora
# Processing Record 44 of Set 9 | adrar
# Processing Record 45 of Set 9 | arcata
# Processing Record 46 of Set 9 | paamiut
# Processing Record 47 of Set 9 | kahului
# Processing Record 48 of Set 9 | iqaluit
# Processing Record 49 of Set 9 | sorkjosen
# Processing Record 50 of Set 9 | narsaq
# Processing Record 1 of Set 10 | bumba
# Processing Record 2 of Set 10 | gomez
# Processing Record 3 of Set 10 | hanmer springs
# Processing Record 4 of Set 10 | kathmandu
# Processing Record 5 of Set 10 | agua caliente de linaca
# City not found. Skipping...
# Processing Record 6 of Set 10 | hudiksvall
# Processing Record 7 of Set 10 | hirara
# Processing Record 8 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 9 of Set 10 | saurimo
# Processing Record 10 of Set 10 | najran
# Processing Record 11 of Set 10 | nanchital
# Processing Record 12 of Set 10 | anori
# Processing Record 13 of Set 10 | qaqortoq
# Processing Record 14 of Set 10 | mackay
# Processing Record 15 of Set 10 | vahan
# Processing Record 16 of Set 10 | muroto
# Processing Record 17 of Set 10 | pachino
# Processing Record 18 of Set 10 | bacuit
# City not found. Skipping...
# Processing Record 19 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 20 of Set 10 | ngemplak
# Processing Record 21 of Set 10 | zhezkazgan
# Processing Record 22 of Set 10 | ketchikan
# Processing Record 23 of Set 10 | dhidhdhoo
# Processing Record 24 of Set 10 | antofagasta
# Processing Record 25 of Set 10 | bukama
# Processing Record 26 of Set 10 | kiama
# Processing Record 27 of Set 10 | nuuk
# Processing Record 28 of Set 10 | minuri
# Processing Record 29 of Set 10 | road town
# Processing Record 30 of Set 10 | san rafael
# Processing Record 31 of Set 10 | kawalu
# Processing Record 32 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 33 of Set 10 | chancay
# Processing Record 34 of Set 10 | christchurch
# Processing Record 35 of Set 10 | kargasok
# Processing Record 36 of Set 10 | batemans bay
# Processing Record 37 of Set 10 | paramonga
# Processing Record 38 of Set 10 | maceio
# Processing Record 39 of Set 10 | chapleau
# Processing Record 40 of Set 10 | pacific grove
# Processing Record 41 of Set 10 | shache
# Processing Record 42 of Set 10 | goderich
# Processing Record 43 of Set 10 | snasa
# Processing Record 44 of Set 10 | udachnyy
# Processing Record 45 of Set 10 | tabory
# Processing Record 46 of Set 10 | saint anthony
# Processing Record 47 of Set 10 | pokhara
# Processing Record 48 of Set 10 | beringovskiy
# Processing Record 49 of Set 10 | port pirie
# Processing Record 50 of Set 10 | komsomolskiy
# Processing Record 1 of Set 11 | sterling
# Processing Record 2 of Set 11 | savalou
# Processing Record 3 of Set 11 | okitipupa
# Processing Record 4 of Set 11 | san quintin
# Processing Record 5 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 11 | tasiilaq
# Processing Record 7 of Set 11 | nanortalik
# Processing Record 8 of Set 11 | atikokan
# Processing Record 9 of Set 11 | acapulco
# Processing Record 10 of Set 11 | springfield
# Processing Record 11 of Set 11 | pedernales
# Processing Record 12 of Set 11 | bilibino
# Processing Record 13 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 11 | warri
# Processing Record 15 of Set 11 | ocos
# Processing Record 16 of Set 11 | sibolga
# Processing Record 17 of Set 11 | beloha
# Processing Record 18 of Set 11 | seydi
# Processing Record 19 of Set 11 | galgani
# City not found. Skipping...
# Processing Record 20 of Set 11 | bairiki
# Processing Record 21 of Set 11 | thisted
# Processing Record 22 of Set 11 | el cobre
# Processing Record 23 of Set 11 | yaan
# Processing Record 24 of Set 11 | comodoro rivadavia
# Processing Record 25 of Set 11 | fort walton beach
# Processing Record 26 of Set 11 | ye
# City not found. Skipping...
# Processing Record 27 of Set 11 | svetlogorsk
# Processing Record 28 of Set 11 | vila
# Processing Record 29 of Set 11 | vanimo
# Processing Record 30 of Set 11 | aykhal
# Processing Record 31 of Set 11 | akdepe
# Processing Record 32 of Set 11 | sechura
# Processing Record 33 of Set 11 | chopinzinho
# Processing Record 34 of Set 11 | sandy bay
# Processing Record 35 of Set 11 | ust-tsilma
# Processing Record 36 of Set 11 | ruteng
# Processing Record 37 of Set 11 | bubaque
# Processing Record 38 of Set 11 | union
# Processing Record 39 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 40 of Set 11 | hofn
# Processing Record 41 of Set 11 | tamandare
# Processing Record 42 of Set 11 | ishcherskaya
# Processing Record 43 of Set 11 | sola
# Processing Record 44 of Set 11 | gat
# Processing Record 45 of Set 11 | jos
# Processing Record 46 of Set 11 | mandalgovi
# Processing Record 47 of Set 11 | shorapur
# Processing Record 48 of Set 11 | mayumba
# Processing Record 49 of Set 11 | port-gentil
# Processing Record 50 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 1 of Set 12 | xiamen
# Processing Record 2 of Set 12 | olinda
# Processing Record 3 of Set 12 | koslan
# Processing Record 4 of Set 12 | bom jesus
# Processing Record 5 of Set 12 | yumen
# Processing Record 6 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 12 | lakes entrance
# Processing Record 8 of Set 12 | port hardy
# Processing Record 9 of Set 12 | saint-paul
# Processing Record 10 of Set 12 | bratsk
# Processing Record 11 of Set 12 | neuquen
# Processing Record 12 of Set 12 | luba
# Processing Record 13 of Set 12 | baracoa
# Processing Record 14 of Set 12 | sakhnovshchyna
# Processing Record 15 of Set 12 | portland
# Processing Record 16 of Set 12 | teguise
# Processing Record 17 of Set 12 | datong
# Processing Record 18 of Set 12 | kargil
# Processing Record 19 of Set 12 | launceston
# Processing Record 20 of Set 12 | rennes
# Processing Record 21 of Set 12 | rocha
# Processing Record 22 of Set 12 | marzuq
# Processing Record 23 of Set 12 | grindavik
# Processing Record 24 of Set 12 | baykit
# Processing Record 25 of Set 12 | pyaozerskiy
# Processing Record 26 of Set 12 | den helder
# Processing Record 27 of Set 12 | svelgen
# Processing Record 28 of Set 12 | ucluelet
# Processing Record 29 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 30 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 31 of Set 12 | ternate
# Processing Record 32 of Set 12 | angoche
# Processing Record 33 of Set 12 | harsin
# Processing Record 34 of Set 12 | kapoeta
# Processing Record 35 of Set 12 | metro
# Processing Record 36 of Set 12 | chongwe
# Processing Record 37 of Set 12 | kununurra
# Processing Record 38 of Set 12 | melilla
# Processing Record 39 of Set 12 | obo
# Processing Record 40 of Set 12 | machacamarca
# Processing Record 41 of Set 12 | evensk
# Processing Record 42 of Set 12 | las cruces
# Processing Record 43 of Set 12 | erzin
# Processing Record 44 of Set 12 | kudahuvadhoo
# Processing Record 45 of Set 12 | balykshi
# Processing Record 46 of Set 12 | buala
# Processing Record 47 of Set 12 | doctor arroyo
# Processing Record 48 of Set 12 | opunake
# Processing Record 49 of Set 12 | verkhoyansk
# Processing Record 50 of Set 12 | barreirinha
# Processing Record 1 of Set 13 | tazovskiy
# Processing Record 2 of Set 13 | burgdorf
# Processing Record 3 of Set 13 | imeni poliny osipenko
# Processing Record 4 of Set 13 | saint-joseph
# Processing Record 5 of Set 13 | omboue
# Processing Record 6 of Set 13 | tuxpan
# Processing Record 7 of Set 13 | yeniseysk
# Processing Record 8 of Set 13 | non sang
# Processing Record 9 of Set 13 | novokayakent
# Processing Record 10 of Set 13 | san cristobal
# Processing Record 11 of Set 13 | praia da vitoria
# Processing Record 12 of Set 13 | haimen
# Processing Record 13 of Set 13 | jizan
# Processing Record 14 of Set 13 | palmerston
# Processing Record 15 of Set 13 | zykovo
# Processing Record 16 of Set 13 | alyangula
# Processing Record 17 of Set 13 | michigan city
# Processing Record 18 of Set 13 | aurora
# Processing Record 19 of Set 13 | mannarakkat
# Processing Record 20 of Set 13 | santa rosa
# Processing Record 21 of Set 13 | smithers
# Processing Record 22 of Set 13 | trogir
# Processing Record 23 of Set 13 | weinan
# Processing Record 24 of Set 13 | praya
# Processing Record 25 of Set 13 | fairview
# Processing Record 26 of Set 13 | sinnamary
# Processing Record 27 of Set 13 | cockburn town
# Processing Record 28 of Set 13 | acuna
# City not found. Skipping...
# Processing Record 29 of Set 13 | ridgecrest
# Processing Record 30 of Set 13 | mehamn
# Processing Record 31 of Set 13 | huarmey
# Processing Record 32 of Set 13 | margate
# Processing Record 33 of Set 13 | lazaro cardenas
# Processing Record 34 of Set 13 | nola
# Processing Record 35 of Set 13 | batticaloa
# Processing Record 36 of Set 13 | oranjemund
# Processing Record 37 of Set 13 | mahaicony
# City not found. Skipping...
# Processing Record 38 of Set 13 | krynychky
# Processing Record 39 of Set 13 | izumo
# Processing Record 40 of Set 13 | concord
# Processing Record 41 of Set 13 | tucumcari
# Processing Record 42 of Set 13 | flinders
# Processing Record 43 of Set 13 | garowe
# Processing Record 44 of Set 13 | tuy hoa
# Processing Record 45 of Set 13 | petropavl
# Processing Record 46 of Set 13 | mapiripan
# Processing Record 47 of Set 13 | moussoro
# Processing Record 48 of Set 13 | independencia
# Processing Record 49 of Set 13 | disna
# Processing Record 50 of Set 13 | antalaha
# Processing Record 1 of Set 14 | veraval
# Processing Record 2 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 3 of Set 14 | uglovskoye
# Processing Record 4 of Set 14 | bonavista
# Processing Record 5 of Set 14 | hay river
# Processing Record 6 of Set 14 | fernley
# Processing Record 7 of Set 14 | leshukonskoye
# Processing Record 8 of Set 14 | petrovsk
# Processing Record 9 of Set 14 | baker city
# Processing Record 10 of Set 14 | mudanjiang
# Processing Record 11 of Set 14 | inhambane
# Processing Record 12 of Set 14 | luwuk
# Processing Record 13 of Set 14 | kabare
# Processing Record 14 of Set 14 | kharan
# Processing Record 15 of Set 14 | ambilobe
# Processing Record 16 of Set 14 | camopi
# Processing Record 17 of Set 14 | asyut
# Processing Record 18 of Set 14 | kismayo
# Processing Record 19 of Set 14 | isabela
# Processing Record 20 of Set 14 | lata
# Processing Record 21 of Set 14 | merauke
# Processing Record 22 of Set 14 | colac
# Processing Record 23 of Set 14 | safford
# Processing Record 24 of Set 14 | atambua
# Processing Record 25 of Set 14 | xiongzhou
# Processing Record 26 of Set 14 | uwayl
# City not found. Skipping...
# Processing Record 27 of Set 14 | kautokeino
# Processing Record 28 of Set 14 | port lincoln
# Processing Record 29 of Set 14 | saint-denis
# Processing Record 30 of Set 14 | tarko-sale
# Processing Record 31 of Set 14 | khasan
# Processing Record 32 of Set 14 | esmeraldas
# Processing Record 33 of Set 14 | amapa
# Processing Record 34 of Set 14 | salcedo
# Processing Record 35 of Set 14 | lorengau
# Processing Record 36 of Set 14 | santiago
# Processing Record 37 of Set 14 | pochutla
# Processing Record 38 of Set 14 | upata
# Processing Record 39 of Set 14 | yirol
# City not found. Skipping...
# Processing Record 40 of Set 14 | guicheng
# City not found. Skipping...
# Processing Record 41 of Set 14 | la libertad
# Processing Record 42 of Set 14 | talakan
# Processing Record 43 of Set 14 | alofi
# Processing Record 44 of Set 14 | agsu
# City not found. Skipping...
# Processing Record 45 of Set 14 | mount isa
# Processing Record 46 of Set 14 | thunder bay
# Processing Record 47 of Set 14 | kem
# Processing Record 48 of Set 14 | opuwo
# Processing Record 49 of Set 14 | mae ramat
# Processing Record 50 of Set 14 | nikolayevsk-na-amure
# Processing Record 1 of Set 15 | malbork
# Processing Record 2 of Set 15 | fare
# Processing Record 3 of Set 15 | dunedin
# Processing Record 4 of Set 15 | ustye
# Processing Record 5 of Set 15 | agirish
# Processing Record 6 of Set 15 | iwaki
# Processing Record 7 of Set 15 | sakakah
# Processing Record 8 of Set 15 | duz
# City not found. Skipping...
# Processing Record 9 of Set 15 | bara
# Processing Record 10 of Set 15 | maues
# Processing Record 11 of Set 15 | rapid valley
# Processing Record 12 of Set 15 | buariki
# City not found. Skipping...
# Processing Record 13 of Set 15 | snyder
# Processing Record 14 of Set 15 | itarema
# Processing Record 15 of Set 15 | raymond terrace
# Processing Record 16 of Set 15 | thabazimbi
# Processing Record 17 of Set 15 | sorong
# Processing Record 18 of Set 15 | nichinan
# Processing Record 19 of Set 15 | manica
# Processing Record 20 of Set 15 | pangai
# Processing Record 21 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 22 of Set 15 | saint-lo
# Processing Record 23 of Set 15 | botwood
# Processing Record 24 of Set 15 | lucea
# Processing Record 25 of Set 15 | enid
# Processing Record 26 of Set 15 | surin
# Processing Record 27 of Set 15 | am timan
# Processing Record 28 of Set 15 | togur
# Processing Record 29 of Set 15 | havre-saint-pierre
# Processing Record 30 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 15 | santa cruz de la palma
# Processing Record 32 of Set 15 | erenhot
# Processing Record 33 of Set 15 | saryshagan
# City not found. Skipping...
# Processing Record 34 of Set 15 | sarai alamgir
# Processing Record 35 of Set 15 | puck
# Processing Record 36 of Set 15 | jumla
# Processing Record 37 of Set 15 | wetzlar
# Processing Record 38 of Set 15 | severo-yeniseyskiy
# Processing Record 39 of Set 15 | susanino
# Processing Record 40 of Set 15 | rio gallegos
# Processing Record 41 of Set 15 | salta
# Processing Record 42 of Set 15 | tagusao
# Processing Record 43 of Set 15 | hokitika
# Processing Record 44 of Set 15 | kota bahru
# Processing Record 45 of Set 15 | dafeng
# Processing Record 46 of Set 15 | karlskrona
# Processing Record 47 of Set 15 | tonekabon
# Processing Record 48 of Set 15 | ixtapa
# Processing Record 49 of Set 15 | sar-e pul
# Processing Record 50 of Set 15 | klyuchi
# Processing Record 1 of Set 16 | great yarmouth
# Processing Record 2 of Set 16 | morden
# Processing Record 3 of Set 16 | inyonga
# Processing Record 4 of Set 16 | gigmoto
# Processing Record 5 of Set 16 | santa margherita ligure
# Processing Record 6 of Set 16 | lagoa da prata
# Processing Record 7 of Set 16 | ratnagiri
# Processing Record 8 of Set 16 | mayo
# Processing Record 9 of Set 16 | rawannawi
# City not found. Skipping...
# Processing Record 10 of Set 16 | southbridge
# Processing Record 11 of Set 16 | jinxiang
# Processing Record 12 of Set 16 | fort saint john
# City not found. Skipping...
# Processing Record 13 of Set 16 | baruun-urt
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFram

# %%
len(city_data)
# Out:
# 700

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hermanus      ZA -34.42   19.23     57.99        86          74
# 1     Mogadishu      SO   2.04   45.34     80.31        77          65
# 2      Katsuura      JP  35.13  140.30     66.00        59           0
# 3        Dikson      RU  73.51   80.55      5.68        95         100
# 4        Harper      LR   4.38   -7.72     77.40        86          17
# 5         Bluff      NZ -46.60  168.33     64.99        62          98
# 6  Punta Arenas      CL -53.15  -70.92     39.20        80          40
# 7    Chokurdakh      RU  70.63  147.92    -17.59        89          32
# 8     Kingsport      US  36.55  -82.56     46.00        75           1
# 9     Mahebourg      MU -20.41   57.70     73.40        94          75
#
#    Wind Speed Current Description
# 0        6.78       broken clouds
# 1        8.34       broken clouds
# 2       11.41           clear sky
# 3       24.72     overcast clouds
# 4        6.20          light rain
# 5       10.00          light rain
# 6       24.16    scattered clouds
# 7        3.98    scattered clouds
# 8        0.67           clear sky
# 9        3.36         shower rain

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# %%
# Create the output file (CSV).
output_data_file = "weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
