# %%
# Create a new set of 2,000 random latitudes and longitudes.

# %%
# Create Latitude and Longitude Combinations

# %%
# import the Pandas, Matplotlib, and NumPy dependencies in the first cell, and run the cell.

# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Get the nearest city using the citipy module.

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Perform an API call with the OpenWeatherMap.

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=32d9b44c37f623141c5d4159e7a8d47e

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Retrieve the following information from the API call:

# Latitude and longitude
# Maximum temperature
# Percent humidity
# Percent cloudiness
# Wind speed
# Weather description (for example, clouds, fog, light rain, clear sky)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": weather_description})
# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | atuona
# Processing Record 2 of Set 1 | lebu
# Processing Record 3 of Set 1 | avarua
# Processing Record 4 of Set 1 | barrow
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | shenxian
# Processing Record 7 of Set 1 | airai
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | nanortalik
# Processing Record 12 of Set 1 | cascais
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | puerto ayora
# Processing Record 15 of Set 1 | nikolskoye
# Processing Record 16 of Set 1 | ratnagiri
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | port elizabeth
# Processing Record 20 of Set 1 | aleksandrov gay
# Processing Record 21 of Set 1 | newport
# Processing Record 22 of Set 1 | cabo san lucas
# Processing Record 23 of Set 1 | skagastrond
# City not found. Skipping...
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | yellowknife
# Processing Record 26 of Set 1 | rikitea
# Processing Record 27 of Set 1 | santa ines
# Processing Record 28 of Set 1 | sao jose da coroa grande
# Processing Record 29 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 30 of Set 1 | abu zabad
# Processing Record 31 of Set 1 | sechura
# Processing Record 32 of Set 1 | hilo
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | faya
# Processing Record 35 of Set 1 | fomboni
# Processing Record 36 of Set 1 | solone
# Processing Record 37 of Set 1 | mar del plata
# Processing Record 38 of Set 1 | aklavik
# Processing Record 39 of Set 1 | arraial do cabo
# Processing Record 40 of Set 1 | kapaa
# Processing Record 41 of Set 1 | thompson
# Processing Record 42 of Set 1 | yar-sale
# Processing Record 43 of Set 1 | saldanha
# Processing Record 44 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 45 of Set 1 | pafos
# Processing Record 46 of Set 1 | praia da vitoria
# Processing Record 47 of Set 1 | carmaux
# Processing Record 48 of Set 1 | kentau
# Processing Record 49 of Set 1 | tura
# Processing Record 50 of Set 1 | faanui
# Processing Record 1 of Set 2 | carnarvon
# Processing Record 2 of Set 2 | artyk
# City not found. Skipping...
# Processing Record 3 of Set 2 | ushuaia
# Processing Record 4 of Set 2 | hermanus
# Processing Record 5 of Set 2 | punto fijo
# Processing Record 6 of Set 2 | capreol
# Processing Record 7 of Set 2 | east london
# Processing Record 8 of Set 2 | lazaro cardenas
# Processing Record 9 of Set 2 | turka
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | dikson
# Processing Record 12 of Set 2 | ribeira grande
# Processing Record 13 of Set 2 | vostok
# Processing Record 14 of Set 2 | busselton
# Processing Record 15 of Set 2 | saskylakh
# Processing Record 16 of Set 2 | upernavik
# Processing Record 17 of Set 2 | yenagoa
# Processing Record 18 of Set 2 | koppang
# Processing Record 19 of Set 2 | samarai
# Processing Record 20 of Set 2 | pahrump
# Processing Record 21 of Set 2 | rapid valley
# Processing Record 22 of Set 2 | chapais
# Processing Record 23 of Set 2 | inuvik
# Processing Record 24 of Set 2 | havre-saint-pierre
# Processing Record 25 of Set 2 | saint george
# Processing Record 26 of Set 2 | darhan
# Processing Record 27 of Set 2 | torbay
# Processing Record 28 of Set 2 | kodiak
# Processing Record 29 of Set 2 | baykit
# Processing Record 30 of Set 2 | ostrovnoy
# Processing Record 31 of Set 2 | severo-kurilsk
# Processing Record 32 of Set 2 | nemuro
# Processing Record 33 of Set 2 | kavieng
# Processing Record 34 of Set 2 | butaritari
# Processing Record 35 of Set 2 | buchanan
# Processing Record 36 of Set 2 | clearwater
# Processing Record 37 of Set 2 | vardo
# Processing Record 38 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 2 | haines junction
# Processing Record 40 of Set 2 | carutapera
# Processing Record 41 of Set 2 | karasburg
# Processing Record 42 of Set 2 | kaitangata
# Processing Record 43 of Set 2 | harrisonburg
# Processing Record 44 of Set 2 | katsuura
# Processing Record 45 of Set 2 | mount gambier
# Processing Record 46 of Set 2 | kavaratti
# Processing Record 47 of Set 2 | vung tau
# Processing Record 48 of Set 2 | salalah
# Processing Record 49 of Set 2 | palaikastron
# Processing Record 50 of Set 2 | bredasdorp
# Processing Record 1 of Set 3 | nouadhibou
# Processing Record 2 of Set 3 | castro
# Processing Record 3 of Set 3 | ponta do sol
# Processing Record 4 of Set 3 | cortes
# Processing Record 5 of Set 3 | khandyga
# Processing Record 6 of Set 3 | verkhnevilyuysk
# Processing Record 7 of Set 3 | cape town
# Processing Record 8 of Set 3 | gamba
# Processing Record 9 of Set 3 | qaanaaq
# Processing Record 10 of Set 3 | albion
# Processing Record 11 of Set 3 | shimoda
# Processing Record 12 of Set 3 | yuanping
# Processing Record 13 of Set 3 | te anau
# Processing Record 14 of Set 3 | caravelas
# Processing Record 15 of Set 3 | bonthe
# Processing Record 16 of Set 3 | hithadhoo
# Processing Record 17 of Set 3 | padang
# Processing Record 18 of Set 3 | sitka
# Processing Record 19 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 3 | xinxiang
# Processing Record 21 of Set 3 | olmos
# Processing Record 22 of Set 3 | chokurdakh
# Processing Record 23 of Set 3 | victor harbor
# Processing Record 24 of Set 3 | taltal
# Processing Record 25 of Set 3 | kaeo
# Processing Record 26 of Set 3 | tuatapere
# Processing Record 27 of Set 3 | cidreira
# Processing Record 28 of Set 3 | raudeberg
# Processing Record 29 of Set 3 | beira
# Processing Record 30 of Set 3 | juneau
# Processing Record 31 of Set 3 | cooma
# Processing Record 32 of Set 3 | port alfred
# Processing Record 33 of Set 3 | bluff
# Processing Record 34 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 35 of Set 3 | tomatlan
# Processing Record 36 of Set 3 | ewa beach
# Processing Record 37 of Set 3 | ferkessedougou
# Processing Record 38 of Set 3 | skibbereen
# Processing Record 39 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 40 of Set 3 | sendai
# Processing Record 41 of Set 3 | mahebourg
# Processing Record 42 of Set 3 | kloulklubed
# Processing Record 43 of Set 3 | dunnville
# Processing Record 44 of Set 3 | beringovskiy
# Processing Record 45 of Set 3 | inhambane
# Processing Record 46 of Set 3 | port lincoln
# Processing Record 47 of Set 3 | den helder
# Processing Record 48 of Set 3 | lorengau
# Processing Record 49 of Set 3 | nhulunbuy
# Processing Record 50 of Set 3 | sungairaya
# Processing Record 1 of Set 4 | sistranda
# Processing Record 2 of Set 4 | kruisfontein
# Processing Record 3 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 4 | clyde river
# Processing Record 5 of Set 4 | fond du lac
# Processing Record 6 of Set 4 | berea
# Processing Record 7 of Set 4 | chabahar
# Processing Record 8 of Set 4 | rantepao
# Processing Record 9 of Set 4 | bengkulu
# Processing Record 10 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 11 of Set 4 | husavik
# Processing Record 12 of Set 4 | atbasar
# Processing Record 13 of Set 4 | mgandu
# Processing Record 14 of Set 4 | la crosse
# Processing Record 15 of Set 4 | villarrica
# Processing Record 16 of Set 4 | tasiilaq
# Processing Record 17 of Set 4 | puerto el triunfo
# Processing Record 18 of Set 4 | norman wells
# Processing Record 19 of Set 4 | outjo
# Processing Record 20 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 21 of Set 4 | kahului
# Processing Record 22 of Set 4 | usinsk
# Processing Record 23 of Set 4 | tevriz
# Processing Record 24 of Set 4 | acari
# Processing Record 25 of Set 4 | berbera
# Processing Record 26 of Set 4 | kanniyakumari
# Processing Record 27 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 4 | lagoa
# Processing Record 29 of Set 4 | ponta delgada
# Processing Record 30 of Set 4 | poso
# Processing Record 31 of Set 4 | san patricio
# Processing Record 32 of Set 4 | namibe
# Processing Record 33 of Set 4 | ndele
# Processing Record 34 of Set 4 | mount isa
# Processing Record 35 of Set 4 | noyabrsk
# Processing Record 36 of Set 4 | ambon
# Processing Record 37 of Set 4 | pentecoste
# Processing Record 38 of Set 4 | berlevag
# Processing Record 39 of Set 4 | meulaboh
# Processing Record 40 of Set 4 | guerrero negro
# Processing Record 41 of Set 4 | bam
# Processing Record 42 of Set 4 | cherskiy
# Processing Record 43 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 44 of Set 4 | altamont
# Processing Record 45 of Set 4 | thai binh
# Processing Record 46 of Set 4 | banda aceh
# Processing Record 47 of Set 4 | iranshahr
# Processing Record 48 of Set 4 | olafsvik
# Processing Record 49 of Set 4 | bambous virieux
# Processing Record 50 of Set 4 | cockburn town
# Processing Record 1 of Set 5 | santa cruz
# Processing Record 2 of Set 5 | kuala kangsar
# Processing Record 3 of Set 5 | new norfolk
# Processing Record 4 of Set 5 | sola
# Processing Record 5 of Set 5 | igarka
# Processing Record 6 of Set 5 | sao lourenco do sul
# Processing Record 7 of Set 5 | great yarmouth
# Processing Record 8 of Set 5 | atasu
# Processing Record 9 of Set 5 | ketchikan
# Processing Record 10 of Set 5 | mayo
# Processing Record 11 of Set 5 | whitehorse
# Processing Record 12 of Set 5 | honiara
# Processing Record 13 of Set 5 | mach
# Processing Record 14 of Set 5 | palembang
# Processing Record 15 of Set 5 | leningradskiy
# Processing Record 16 of Set 5 | bereda
# Processing Record 17 of Set 5 | cururupu
# Processing Record 18 of Set 5 | lata
# Processing Record 19 of Set 5 | longyearbyen
# Processing Record 20 of Set 5 | krasne
# Processing Record 21 of Set 5 | eureka
# Processing Record 22 of Set 5 | nome
# Processing Record 23 of Set 5 | visp
# Processing Record 24 of Set 5 | ligayan
# Processing Record 25 of Set 5 | ilulissat
# Processing Record 26 of Set 5 | mogzon
# Processing Record 27 of Set 5 | saint-paul
# Processing Record 28 of Set 5 | kununurra
# Processing Record 29 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 30 of Set 5 | bethel
# Processing Record 31 of Set 5 | pionerskiy
# Processing Record 32 of Set 5 | bacolod
# Processing Record 33 of Set 5 | georgetown
# Processing Record 34 of Set 5 | grindavik
# Processing Record 35 of Set 5 | mehamn
# Processing Record 36 of Set 5 | koumac
# Processing Record 37 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 39 of Set 5 | anito
# Processing Record 40 of Set 5 | hasaki
# Processing Record 41 of Set 5 | zhangye
# Processing Record 42 of Set 5 | les cayes
# Processing Record 43 of Set 5 | zhob
# Processing Record 44 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 45 of Set 5 | khatanga
# Processing Record 46 of Set 5 | alugan
# Processing Record 47 of Set 5 | tuktoyaktuk
# Processing Record 48 of Set 5 | polis
# Processing Record 49 of Set 5 | bambanglipuro
# Processing Record 50 of Set 5 | altay
# Processing Record 1 of Set 6 | boa vista
# Processing Record 2 of Set 6 | dibaya
# City not found. Skipping...
# Processing Record 3 of Set 6 | maloshuyka
# City not found. Skipping...
# Processing Record 4 of Set 6 | vila franca do campo
# Processing Record 5 of Set 6 | solsvik
# City not found. Skipping...
# Processing Record 6 of Set 6 | tiksi
# Processing Record 7 of Set 6 | provideniya
# Processing Record 8 of Set 6 | abu samrah
# Processing Record 9 of Set 6 | maues
# Processing Record 10 of Set 6 | san quintin
# Processing Record 11 of Set 6 | the valley
# Processing Record 12 of Set 6 | rawson
# Processing Record 13 of Set 6 | poum
# Processing Record 14 of Set 6 | rajshahi
# Processing Record 15 of Set 6 | port hardy
# Processing Record 16 of Set 6 | monte patria
# Processing Record 17 of Set 6 | vila nova de milfontes
# Processing Record 18 of Set 6 | ahipara
# Processing Record 19 of Set 6 | arrecife
# Processing Record 20 of Set 6 | lima
# Processing Record 21 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 22 of Set 6 | aringay
# Processing Record 23 of Set 6 | cap malheureux
# Processing Record 24 of Set 6 | zaraza
# Processing Record 25 of Set 6 | margate
# Processing Record 26 of Set 6 | sao joao da barra
# Processing Record 27 of Set 6 | kangaatsiaq
# Processing Record 28 of Set 6 | henties bay
# Processing Record 29 of Set 6 | povenets
# Processing Record 30 of Set 6 | madang
# Processing Record 31 of Set 6 | saint-philippe
# Processing Record 32 of Set 6 | bubaque
# Processing Record 33 of Set 6 | bodrum
# Processing Record 34 of Set 6 | necochea
# Processing Record 35 of Set 6 | kholm-zhirkovskiy
# Processing Record 36 of Set 6 | san pedro
# Processing Record 37 of Set 6 | anori
# Processing Record 38 of Set 6 | bustonkala
# City not found. Skipping...
# Processing Record 39 of Set 6 | zalari
# Processing Record 40 of Set 6 | okhotsk
# Processing Record 41 of Set 6 | poltavka
# Processing Record 42 of Set 6 | kipushi
# Processing Record 43 of Set 6 | kaputa
# Processing Record 44 of Set 6 | isangel
# Processing Record 45 of Set 6 | ozgon
# City not found. Skipping...
# Processing Record 46 of Set 6 | laguna
# Processing Record 47 of Set 6 | rocha
# Processing Record 48 of Set 6 | labuhan
# Processing Record 49 of Set 6 | namtsy
# Processing Record 50 of Set 6 | bay city
# Processing Record 1 of Set 7 | ucluelet
# Processing Record 2 of Set 7 | lemesos
# City not found. Skipping...
# Processing Record 3 of Set 7 | fortuna
# Processing Record 4 of Set 7 | astoria
# Processing Record 5 of Set 7 | okha
# Processing Record 6 of Set 7 | constitucion
# Processing Record 7 of Set 7 | arlit
# Processing Record 8 of Set 7 | ornskoldsvik
# Processing Record 9 of Set 7 | nantucket
# Processing Record 10 of Set 7 | tuggurt
# City not found. Skipping...
# Processing Record 11 of Set 7 | ancud
# Processing Record 12 of Set 7 | itaituba
# Processing Record 13 of Set 7 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 14 of Set 7 | pevek
# Processing Record 15 of Set 7 | kijang
# Processing Record 16 of Set 7 | atherton
# Processing Record 17 of Set 7 | mazatlan
# Processing Record 18 of Set 7 | oktyabrskiy
# Processing Record 19 of Set 7 | emba
# Processing Record 20 of Set 7 | bonavista
# Processing Record 21 of Set 7 | amahai
# Processing Record 22 of Set 7 | markkleeberg
# Processing Record 23 of Set 7 | nagapattinam
# Processing Record 24 of Set 7 | bandarbeyla
# Processing Record 25 of Set 7 | pital
# Processing Record 26 of Set 7 | walvis bay
# Processing Record 27 of Set 7 | belmonte
# Processing Record 28 of Set 7 | tautira
# Processing Record 29 of Set 7 | shwebo
# Processing Record 30 of Set 7 | tera
# Processing Record 31 of Set 7 | karratha
# Processing Record 32 of Set 7 | aripuana
# Processing Record 33 of Set 7 | marrakesh
# Processing Record 34 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 35 of Set 7 | dongsheng
# Processing Record 36 of Set 7 | pinhao
# Processing Record 37 of Set 7 | novopetrovskoye
# Processing Record 38 of Set 7 | tumannyy
# City not found. Skipping...
# Processing Record 39 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 40 of Set 7 | hammerfest
# Processing Record 41 of Set 7 | ust-nera
# Processing Record 42 of Set 7 | charleston
# Processing Record 43 of Set 7 | novoagansk
# Processing Record 44 of Set 7 | ganzhou
# Processing Record 45 of Set 7 | valparaiso
# Processing Record 46 of Set 7 | christchurch
# Processing Record 47 of Set 7 | choya
# Processing Record 48 of Set 7 | prince george
# Processing Record 49 of Set 7 | port hedland
# Processing Record 50 of Set 7 | mahabad
# Processing Record 1 of Set 8 | sonamura
# Processing Record 2 of Set 8 | vanimo
# Processing Record 3 of Set 8 | zhigansk
# Processing Record 4 of Set 8 | bara
# Processing Record 5 of Set 8 | gladstone
# Processing Record 6 of Set 8 | rio grande
# Processing Record 7 of Set 8 | bemidji
# Processing Record 8 of Set 8 | bodden town
# Processing Record 9 of Set 8 | nagato
# Processing Record 10 of Set 8 | ilhabela
# Processing Record 11 of Set 8 | lompoc
# Processing Record 12 of Set 8 | port macquarie
# Processing Record 13 of Set 8 | bedele
# Processing Record 14 of Set 8 | murgab
# Processing Record 15 of Set 8 | cam ranh
# Processing Record 16 of Set 8 | najran
# Processing Record 17 of Set 8 | gasa
# Processing Record 18 of Set 8 | bilma
# Processing Record 19 of Set 8 | san lazaro
# Processing Record 20 of Set 8 | kutum
# Processing Record 21 of Set 8 | namikupa
# Processing Record 22 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 23 of Set 8 | anloga
# Processing Record 24 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 25 of Set 8 | birao
# Processing Record 26 of Set 8 | san carlos de bariloche
# Processing Record 27 of Set 8 | praia
# Processing Record 28 of Set 8 | atar
# Processing Record 29 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 30 of Set 8 | belle fourche
# Processing Record 31 of Set 8 | blyth
# Processing Record 32 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 8 | fairbanks
# Processing Record 34 of Set 8 | kholtoson
# Processing Record 35 of Set 8 | marfino
# Processing Record 36 of Set 8 | kashi
# Processing Record 37 of Set 8 | komsomolskiy
# Processing Record 38 of Set 8 | naron
# Processing Record 39 of Set 8 | solnechnyy
# Processing Record 40 of Set 8 | yerazgavors
# Processing Record 41 of Set 8 | vuktyl
# Processing Record 42 of Set 8 | broome
# Processing Record 43 of Set 8 | auki
# Processing Record 44 of Set 8 | krasnaya gorka
# Processing Record 45 of Set 8 | souillac
# Processing Record 46 of Set 8 | mubi
# Processing Record 47 of Set 8 | san lorenzo
# Processing Record 48 of Set 8 | canakkale
# Processing Record 49 of Set 8 | victoria
# Processing Record 50 of Set 8 | buala
# Processing Record 1 of Set 9 | eruwa
# Processing Record 2 of Set 9 | bathsheba
# Processing Record 3 of Set 9 | maravatio
# Processing Record 4 of Set 9 | huarmey
# Processing Record 5 of Set 9 | krasnyy yar
# Processing Record 6 of Set 9 | gimli
# Processing Record 7 of Set 9 | kokopo
# Processing Record 8 of Set 9 | botucatu
# Processing Record 9 of Set 9 | ponca city
# Processing Record 10 of Set 9 | constantine
# Processing Record 11 of Set 9 | rio gallegos
# Processing Record 12 of Set 9 | xinyang
# Processing Record 13 of Set 9 | olinda
# Processing Record 14 of Set 9 | la sarre
# Processing Record 15 of Set 9 | midyat
# Processing Record 16 of Set 9 | udachnyy
# Processing Record 17 of Set 9 | yermakovskoye
# Processing Record 18 of Set 9 | maceio
# Processing Record 19 of Set 9 | gibara
# Processing Record 20 of Set 9 | svetlyy
# Processing Record 21 of Set 9 | wanaka
# Processing Record 22 of Set 9 | nuuk
# Processing Record 23 of Set 9 | puerto colombia
# Processing Record 24 of Set 9 | makakilo city
# Processing Record 25 of Set 9 | del rio
# Processing Record 26 of Set 9 | yeletskiy
# City not found. Skipping...
# Processing Record 27 of Set 9 | seguela
# Processing Record 28 of Set 9 | waipawa
# Processing Record 29 of Set 9 | chengde
# Processing Record 30 of Set 9 | beecher
# Processing Record 31 of Set 9 | sioux lookout
# Processing Record 32 of Set 9 | anthia
# City not found. Skipping...
# Processing Record 33 of Set 9 | key west
# Processing Record 34 of Set 9 | mocambique
# City not found. Skipping...
# Processing Record 35 of Set 9 | mago
# Processing Record 36 of Set 9 | jatiroto
# Processing Record 37 of Set 9 | sinnamary
# Processing Record 38 of Set 9 | alofi
# Processing Record 39 of Set 9 | vao
# Processing Record 40 of Set 9 | san vicente
# Processing Record 41 of Set 9 | carbonia
# Processing Record 42 of Set 9 | sept-iles
# Processing Record 43 of Set 9 | krasnyy mayak
# City not found. Skipping...
# Processing Record 44 of Set 9 | wattegama
# Processing Record 45 of Set 9 | kapit
# Processing Record 46 of Set 9 | vila velha
# Processing Record 47 of Set 9 | bud
# Processing Record 48 of Set 9 | buin
# Processing Record 49 of Set 9 | tzucacab
# Processing Record 50 of Set 9 | quatre cocos
# Processing Record 1 of Set 10 | zlatoustovsk
# City not found. Skipping...
# Processing Record 2 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 10 | barstow
# Processing Record 4 of Set 10 | umm ruwabah
# City not found. Skipping...
# Processing Record 5 of Set 10 | northam
# Processing Record 6 of Set 10 | baturite
# Processing Record 7 of Set 10 | kalmunai
# Processing Record 8 of Set 10 | tateyama
# Processing Record 9 of Set 10 | klaksvik
# Processing Record 10 of Set 10 | dedza
# Processing Record 11 of Set 10 | alma
# Processing Record 12 of Set 10 | zaliznychne
# Processing Record 13 of Set 10 | florence
# Processing Record 14 of Set 10 | marzuq
# Processing Record 15 of Set 10 | ranong
# Processing Record 16 of Set 10 | narsaq
# Processing Record 17 of Set 10 | smidovich
# Processing Record 18 of Set 10 | sambava
# Processing Record 19 of Set 10 | dunhua
# Processing Record 20 of Set 10 | roebourne
# Processing Record 21 of Set 10 | miri
# Processing Record 22 of Set 10 | deputatskiy
# Processing Record 23 of Set 10 | maltahohe
# Processing Record 24 of Set 10 | andevoranto
# City not found. Skipping...
# Processing Record 25 of Set 10 | masuguru
# Processing Record 26 of Set 10 | maryville
# Processing Record 27 of Set 10 | tvoroyri
# Processing Record 28 of Set 10 | dunedin
# Processing Record 29 of Set 10 | brae
# Processing Record 30 of Set 10 | tombouctou
# Processing Record 31 of Set 10 | khlung
# Processing Record 32 of Set 10 | alexandria
# Processing Record 33 of Set 10 | himora
# City not found. Skipping...
# Processing Record 34 of Set 10 | ostersund
# Processing Record 35 of Set 10 | tromso
# Processing Record 36 of Set 10 | two rivers
# Processing Record 37 of Set 10 | ixtapa
# Processing Record 38 of Set 10 | severnoye
# Processing Record 39 of Set 10 | shubarkuduk
# Processing Record 40 of Set 10 | mao
# Processing Record 41 of Set 10 | gisborne
# Processing Record 42 of Set 10 | qasigiannguit
# Processing Record 43 of Set 10 | salto del guaira
# Processing Record 44 of Set 10 | bykov
# Processing Record 45 of Set 10 | talcahuano
# Processing Record 46 of Set 10 | leh
# Processing Record 47 of Set 10 | prince rupert
# Processing Record 48 of Set 10 | progreso
# Processing Record 49 of Set 10 | guekedou
# City not found. Skipping...
# Processing Record 50 of Set 10 | iqaluit
# Processing Record 1 of Set 11 | santiago del estero
# Processing Record 2 of Set 11 | fort-shevchenko
# Processing Record 3 of Set 11 | aykhal
# Processing Record 4 of Set 11 | minna
# Processing Record 5 of Set 11 | kathmandu
# Processing Record 6 of Set 11 | cabedelo
# Processing Record 7 of Set 11 | trinidad
# Processing Record 8 of Set 11 | guanhaes
# Processing Record 9 of Set 11 | navahrudak
# Processing Record 10 of Set 11 | moroni
# Processing Record 11 of Set 11 | luderitz
# Processing Record 12 of Set 11 | yulara
# Processing Record 13 of Set 11 | sarkand
# Processing Record 14 of Set 11 | byron bay
# Processing Record 15 of Set 11 | nioki
# Processing Record 16 of Set 11 | tilichiki
# Processing Record 17 of Set 11 | dubbo
# Processing Record 18 of Set 11 | sterling
# Processing Record 19 of Set 11 | bingol
# Processing Record 20 of Set 11 | alyangula
# Processing Record 21 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 22 of Set 11 | matara
# Processing Record 23 of Set 11 | biak
# Processing Record 24 of Set 11 | magdalena
# Processing Record 25 of Set 11 | asfi
# Processing Record 26 of Set 11 | nguiu
# City not found. Skipping...
# Processing Record 27 of Set 11 | teguise
# Processing Record 28 of Set 11 | itajuba
# Processing Record 29 of Set 11 | vrangel
# Processing Record 30 of Set 11 | arman
# Processing Record 31 of Set 11 | chuy
# Processing Record 32 of Set 11 | morant bay
# Processing Record 33 of Set 11 | ternate
# Processing Record 34 of Set 11 | manggar
# Processing Record 35 of Set 11 | navabad
# City not found. Skipping...
# Processing Record 36 of Set 11 | vermillion
# Processing Record 37 of Set 11 | dingle
# Processing Record 38 of Set 11 | sao filipe
# Processing Record 39 of Set 11 | teya
# Processing Record 40 of Set 11 | anamur
# Processing Record 41 of Set 11 | soyo
# Processing Record 42 of Set 11 | laurel
# Processing Record 43 of Set 11 | pitogo
# Processing Record 44 of Set 11 | asola
# Processing Record 45 of Set 11 | trelew
# Processing Record 46 of Set 11 | smolenka
# Processing Record 47 of Set 11 | zhezkazgan
# Processing Record 48 of Set 11 | iwaki
# Processing Record 49 of Set 11 | bucov
# Processing Record 50 of Set 11 | barcelos
# Processing Record 1 of Set 12 | japura
# Processing Record 2 of Set 12 | khipro
# Processing Record 3 of Set 12 | teluk intan
# Processing Record 4 of Set 12 | kirakira
# Processing Record 5 of Set 12 | hofn
# Processing Record 6 of Set 12 | jibuti
# Processing Record 7 of Set 12 | la romana
# Processing Record 8 of Set 12 | sarangani
# Processing Record 9 of Set 12 | geraldton
# Processing Record 10 of Set 12 | bridlington
# Processing Record 11 of Set 12 | baiao
# Processing Record 12 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 12 | cap-aux-meules
# Processing Record 14 of Set 12 | doha
# Processing Record 15 of Set 12 | rasht
# Processing Record 16 of Set 12 | talara
# Processing Record 17 of Set 12 | pangnirtung
# Processing Record 18 of Set 12 | atambua
# Processing Record 19 of Set 12 | lavrentiya
# Processing Record 20 of Set 12 | naze
# Processing Record 21 of Set 12 | susehri
# Processing Record 22 of Set 12 | tynda
# Processing Record 23 of Set 12 | poya
# Processing Record 24 of Set 12 | at-bashi
# Processing Record 25 of Set 12 | manzanillo
# Processing Record 26 of Set 12 | tyrma
# Processing Record 27 of Set 12 | morondava
# Processing Record 28 of Set 12 | svetlaya
# Processing Record 29 of Set 12 | isiro
# Processing Record 30 of Set 12 | sesheke
# Processing Record 31 of Set 12 | sampit
# Processing Record 32 of Set 12 | shaunavon
# Processing Record 33 of Set 12 | pueblo
# Processing Record 34 of Set 12 | verkhoyansk
# Processing Record 35 of Set 12 | parrita
# Processing Record 36 of Set 12 | mogadishu
# Processing Record 37 of Set 12 | denpasar
# Processing Record 38 of Set 12 | maniitsoq
# Processing Record 39 of Set 12 | teguldet
# Processing Record 40 of Set 12 | tocopilla
# Processing Record 41 of Set 12 | copiapo
# Processing Record 42 of Set 12 | oussouye
# Processing Record 43 of Set 12 | belaya kholunitsa
# Processing Record 44 of Set 12 | codrington
# Processing Record 45 of Set 12 | gouyave
# Processing Record 46 of Set 12 | calama
# Processing Record 47 of Set 12 | sabang
# Processing Record 48 of Set 12 | brainerd
# Processing Record 49 of Set 12 | rio rancho
# Processing Record 50 of Set 12 | portland
# Processing Record 1 of Set 13 | kristiansund
# Processing Record 2 of Set 13 | anadyr
# Processing Record 3 of Set 13 | buzmeyin
# Processing Record 4 of Set 13 | pisco
# Processing Record 5 of Set 13 | beloha
# Processing Record 6 of Set 13 | hovd
# Processing Record 7 of Set 13 | sayula
# Processing Record 8 of Set 13 | senanga
# Processing Record 9 of Set 13 | higuey
# City not found. Skipping...
# Processing Record 10 of Set 13 | pringsewu
# Processing Record 11 of Set 13 | evensk
# Processing Record 12 of Set 13 | westlock
# Processing Record 13 of Set 13 | liverpool
# Processing Record 14 of Set 13 | champasak
# Processing Record 15 of Set 13 | kabelvag
# Processing Record 16 of Set 13 | preobrazheniye
# Processing Record 17 of Set 13 | tauranga
# Processing Record 18 of Set 13 | lampang
# Processing Record 19 of Set 13 | yangambi
# Processing Record 20 of Set 13 | puerto madryn
# Processing Record 21 of Set 13 | sakata
# Processing Record 22 of Set 13 | paamiut
# Processing Record 23 of Set 13 | talnakh
# Processing Record 24 of Set 13 | kyshtovka
# Processing Record 25 of Set 13 | luganville
# Processing Record 26 of Set 13 | emerald
# Processing Record 27 of Set 13 | acajutla
# Processing Record 28 of Set 13 | vryburg
# Processing Record 29 of Set 13 | manono
# Processing Record 30 of Set 13 | oranjestad
# Processing Record 31 of Set 13 | chodavaram
# Processing Record 32 of Set 13 | nago
# Processing Record 33 of Set 13 | paita
# Processing Record 34 of Set 13 | farrukhnagar
# Processing Record 35 of Set 13 | flores
# Processing Record 36 of Set 13 | cortez
# Processing Record 37 of Set 13 | mattru
# Processing Record 38 of Set 13 | esperance
# Processing Record 39 of Set 13 | moses lake
# Processing Record 40 of Set 13 | taoudenni
# Processing Record 41 of Set 13 | shingu
# Processing Record 42 of Set 13 | omboue
# Processing Record 43 of Set 13 | bollnas
# Processing Record 44 of Set 13 | mumford
# Processing Record 45 of Set 13 | chesma
# Processing Record 46 of Set 13 | geneva
# Processing Record 47 of Set 13 | mandalgovi
# Processing Record 48 of Set 13 | itapua poty
# City not found. Skipping...
# Processing Record 49 of Set 13 | george
# Processing Record 50 of Set 13 | muika
# City not found. Skipping...
# Processing Record 1 of Set 14 | minsk
# Processing Record 2 of Set 14 | khrebtovaya
# Processing Record 3 of Set 14 | panorama
# Processing Record 4 of Set 14 | kolobrzeg
# Processing Record 5 of Set 14 | andros town
# Processing Record 6 of Set 14 | burgeo
# Processing Record 7 of Set 14 | zhitikara
# City not found. Skipping...
# Processing Record 8 of Set 14 | chalus
# Processing Record 9 of Set 14 | along
# Processing Record 10 of Set 14 | odweyne
# Processing Record 11 of Set 14 | zimovniki
# Processing Record 12 of Set 14 | neuquen
# Processing Record 13 of Set 14 | coquimbo
# Processing Record 14 of Set 14 | riberalta
# Processing Record 15 of Set 14 | sereflikochisar
# Processing Record 16 of Set 14 | banyo
# Processing Record 17 of Set 14 | zheleznodorozhnyy
# Processing Record 18 of Set 14 | simpang
# Processing Record 19 of Set 14 | daultala
# Processing Record 20 of Set 14 | fort wayne
# Processing Record 21 of Set 14 | zurrieq
# Processing Record 22 of Set 14 | amapa
# Processing Record 23 of Set 14 | north bend
# Processing Record 24 of Set 14 | port augusta
# Processing Record 25 of Set 14 | ahmadpur
# Processing Record 26 of Set 14 | williams lake
# Processing Record 27 of Set 14 | roald
# Processing Record 28 of Set 14 | anar darreh
# City not found. Skipping...
# Processing Record 29 of Set 14 | san isidro
# Processing Record 30 of Set 14 | kieta
# Processing Record 31 of Set 14 | jalu
# Processing Record 32 of Set 14 | kodinsk
# Processing Record 33 of Set 14 | meadow lake
# Processing Record 34 of Set 14 | seoul
# Processing Record 35 of Set 14 | kiama
# Processing Record 36 of Set 14 | lalibela
# Processing Record 37 of Set 14 | sandwick
# Processing Record 38 of Set 14 | wagar
# Processing Record 39 of Set 14 | troitskoye
# Processing Record 40 of Set 14 | mayna
# Processing Record 41 of Set 14 | dzhebariki-khaya
# Processing Record 42 of Set 14 | micheweni
# Processing Record 43 of Set 14 | kiruna
# Processing Record 44 of Set 14 | tieli
# Processing Record 45 of Set 14 | sobolevo
# Processing Record 46 of Set 14 | phalaborwa
# Processing Record 47 of Set 14 | skalistyy
# City not found. Skipping...
# Processing Record 48 of Set 14 | onega
# Processing Record 49 of Set 14 | yatou
# Processing Record 50 of Set 14 | panuco
# Processing Record 1 of Set 15 | ventspils
# Processing Record 2 of Set 15 | pueblo nuevo
# Processing Record 3 of Set 15 | jiaocheng
# Processing Record 4 of Set 15 | lasa
# Processing Record 5 of Set 15 | shubarshi
# Processing Record 6 of Set 15 | darlowo
# Processing Record 7 of Set 15 | palmer
# Processing Record 8 of Set 15 | taganak
# Processing Record 9 of Set 15 | show low
# Processing Record 10 of Set 15 | chanderi
# Processing Record 11 of Set 15 | kupang
# Processing Record 12 of Set 15 | dolbeau
# City not found. Skipping...
# Processing Record 13 of Set 15 | linkou
# Processing Record 14 of Set 15 | basco
# Processing Record 15 of Set 15 | college
# Processing Record 16 of Set 15 | porto murtinho
# Processing Record 17 of Set 15 | kamenka
# Processing Record 18 of Set 15 | altamira
# Processing Record 19 of Set 15 | bulgan
# Processing Record 20 of Set 15 | zelenoborsk
# Processing Record 21 of Set 15 | seymchan
# Processing Record 22 of Set 15 | manaure
# Processing Record 23 of Set 15 | itaqui
# Processing Record 24 of Set 15 | menongue
# Processing Record 25 of Set 15 | tir pol
# City not found. Skipping...
# Processing Record 26 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 27 of Set 15 | maningrida
# Processing Record 28 of Set 15 | aswan
# Processing Record 29 of Set 15 | grand-santi
# Processing Record 30 of Set 15 | mangrol
# Processing Record 31 of Set 15 | monte alegre de sergipe
# Processing Record 32 of Set 15 | coos bay
# Processing Record 33 of Set 15 | pocoes
# Processing Record 34 of Set 15 | saryozek
# Processing Record 35 of Set 15 | jumla
# Processing Record 36 of Set 15 | batemans bay
# Processing Record 37 of Set 15 | trabzon
# Processing Record 38 of Set 15 | la ronge
# Processing Record 39 of Set 15 | gizo
# Processing Record 40 of Set 15 | bukama
# Processing Record 41 of Set 15 | tavda
# Processing Record 42 of Set 15 | kovdor
# Processing Record 43 of Set 15 | erenhot
# Processing Record 44 of Set 15 | saint-francois
# Processing Record 45 of Set 15 | alice springs
# Processing Record 46 of Set 15 | moussoro
# Processing Record 47 of Set 15 | zavetnoye
# Processing Record 48 of Set 15 | kudahuvadhoo
# Processing Record 49 of Set 15 | oban
# Processing Record 50 of Set 15 | sisimiut
# Processing Record 1 of Set 16 | voznesenskoye
# Processing Record 2 of Set 16 | tsaratanana
# Processing Record 3 of Set 16 | lykhivka
# Processing Record 4 of Set 16 | avera
# Processing Record 5 of Set 16 | acapulco
# Processing Record 6 of Set 16 | kushima
# Processing Record 7 of Set 16 | rock sound
# Processing Record 8 of Set 16 | pemberton
# Processing Record 9 of Set 16 | domna
# Processing Record 10 of Set 16 | kralendijk
# Processing Record 11 of Set 16 | san juan de uraba
# Processing Record 12 of Set 16 | filadelfia
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Add the data to a new DataFram

# %%
len(city_data)
# Out:
# 703

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0      Atuona  -9.80 -139.03     77.61        76          85       15.79
# 1        Lebu -37.62  -73.65     54.39        86           3        9.80
# 2      Avarua -21.21 -159.78     80.60        69           7        5.82
# 3      Barrow  71.29 -156.79     17.60        85          90       14.99
# 4    Shenxian  36.24  115.67     48.87        82          91        5.23
# 5       Airai  -8.93  125.41     71.02        57           0        1.25
# 6     Mataura -46.19  168.86     66.99        54         100       10.00
# 7   Jamestown  42.10  -79.24     45.00        86          90       10.29
# 8  Nanortalik  60.14  -45.24     28.54        88         100        6.08
# 9     Cascais  38.70   -9.42     64.00        98          93       11.27
#
#     Current Description
# 0       overcast clouds
# 1             clear sky
# 2             clear sky
# 3                  mist
# 4       overcast clouds
# 5             clear sky
# 6  heavy intensity rain
# 7       overcast clouds
# 8       overcast clouds
# 9       overcast clouds

# %%
# Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.

# %%
# Create the output file (CSV).
output_data_file = "weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
